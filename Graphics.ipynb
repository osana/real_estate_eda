# %% [markdown]
# # Анализ данных по графикам

# %%
import re
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import requests
path = "./datasets/_data_fixed.csv"
rent = pd.read_csv(path)
rent.dtypes
# Out:
# ID  объявления          int64
# Количество комнат      object
# Метро                  object
# Адрес                  object
# square_total          float64
# Дом                    object
# parking                object
# Цена                   object
# renovation             object
# Площадь комнат, м2     object
# Балкон                 object
# windows                object
# Санузел                object
# Дополнительно          object
# Название ЖК            object
# Высота потолков, м    float64
# Лифт                   object
# garbage_chute           int64
# price_rub_month         int64
# kids_allowed            int64
# pets_allowed            int64
# dtype: object

# %% [markdown]
# #### Зависмость площади квартиры от стоимости аренды в месяц

# %%
sns.scatterplot(data=rent, x='price_rub_month', y='square_total')
# Out:
# <Axes: xlabel='price_rub_month', ylabel='square_total'>
